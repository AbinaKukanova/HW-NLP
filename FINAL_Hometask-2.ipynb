# %% [markdown]
# # Домашнее задание №2
#
# В этой домашке вам будет нужно найти тексты на русском языке (размер корпуса не менее 200 слов), в которых будут какие-то трудные или неоднозначные для POS теггинга моменты и разметить их вручную – с помощью этих текстов мы будем оценивать качество работы наших теггеров. В текстах размечаем только части речи, ничего больше!
#
# (1 балл) Создание, разметка корпуса и объяснение того, почему этот текст подходит для оценки (какие моменты вы тут считаете трудными для автоматического посттеггинга и почему, в этом вам может помочь второй ридинг). Не забывайте, что разные теггеры могут использовать разные тегсеты: напишите комментарий о том, какой тегсет вы берёте для разметки и почему.

# %%
#импортируем нужные библиотеки
import pandas as pd
from pymorphy2 import MorphAnalyzer
morph = MorphAnalyzer()
from pymystem3 import Mystem
m = Mystem()
from pprint import pprint
import spacy
from nltk.tokenize import word_tokenize
nlp = spacy.load("ru_core_news_sm")

# %% [markdown]
# В корпус я включила слова с неизвестными словарю корнем, но образованные с помощью продуктивных аффиксов, авторские "придуманные слова", сложные слова, у которых вторая часть совпадает со словами в словаре Зализняка, слова с неизвестными корнями без продуктивных суффиксов, редкие и нестандартные формы, которые признаются ненормативными или окказиональными в языке и аббвериатуры. Для разметки я использовала граммемы, которые используются в pymorphy2 для русского языка, в pymorphy2 используются словари OpenCoprora и граммемы, принятые в OpenCorpora с небольшими изменениями.

# %%
korpus = pd.read_csv('final_korpus.csv', sep = ';')

# %%
pos_taggers = []
for pos_tager in korpus['POS']:
    pos_taggers.append(pos_tager)

pos_taggers
# Out:
# ['ADJF',
#  'NOUN',
#  'ADJF',
#  'NOUN',
#  'ADJF',
#  'ADJF',
#  'NOUN',
#  'VERB',
#  'ADJF',
#  'ADJF',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'ADJF',
#  'ADJF',
#  'ADJF',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'ADJF',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'GRND',
#  'GRND',
#  'GRND',
#  'ADJF',
#  'ADVB',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'VERB',
#  'VERB',
#  'VERB',
#  'VERB',
#  'VERB',
#  'VERB',
#  'VERB',
#  'ADVB',
#  'VERB',
#  'VERB',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'VERB',
#  'VERB',
#  'ADJF',
#  'NOUN',
#  'VERB',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'VERB',
#  'ADVB',
#  'ADVB',
#  'ADVB',
#  'ADVB',
#  'ADVB',
#  'ADJF',
#  'NOUN',
#  'VERB',
#  'ADJF',
#  'GRND',
#  'ADJF',
#  'VERB',
#  'VERB',
#  'GRND',
#  'ADJF',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'VERB',
#  'ADJF',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'ADJS',
#  'ADJF',
#  'NOUN',
#  'GRND',
#  'PRTF',
#  'GRND',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'ADVB',
#  'NOUN',
#  'ADJF',
#  'ADVB',
#  'GRND',
#  'NOUN',
#  'PRTS',
#  'ADJF',
#  'VERB',
#  'GRND',
#  'GRND',
#  'ADJF',
#  'NOUN',
#  'PRTS',
#  'VERB',
#  'GRND',
#  'VERB',
#  'GRND',
#  'NOUN',
#  'GRND',
#  'NOUN',
#  'ADJF',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'GRND',
#  'ADJF',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'ADVB',
#  'ADVB',
#  'GRND',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADJF',
#  'ADJF',
#  'NOUN',
#  'ADVB',
#  'ADJF',
#  'ADJF',
#  'VERB',
#  'VERB',
#  'VERB',
#  'NOUN',
#  'GRND',
#  'NOUN',
#  'ADVB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'GRND',
#  'NOUN',
#  'ADJF',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'GRND',
#  'GRND',
#  'GRND',
#  'ADJF',
#  'NOUN',
#  'ADJF',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'VERB',
#  'ADJF',
#  'ADVB',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'ADJF',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'ADVB',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'ADVB',
#  'NOUN',
#  'VERB',
#  'ADJF',
#  'ADJF',
#  'ADVB',
#  'NOUN',
#  'ADJF',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB']

# %% [markdown]
# # Второе и Третье задание
# Потом вам будет нужно взять три POS теггера для русского языка (udpipe, stanza, natasha, pymorphy, mystem, spacy, deeppavlov) и «прогнать» текст через каждый из них.Затем оценим accuracy для каждого теггера. Заметьте, что в разных системах имена тегов и части речи могут отличаться, – вам надо будет свести это всё к единому стандарту с помощью какой-то функции-конвертера и сравнить с вашим размеченным руками эталоном - тоже с помощью какого-то кода или функции.

# %%
# spacy pos tagger
spacy_taggers = []
for line in korpus['Word']:
    spacy_taggers.append(nlp(line)[0].pos_)

# %%
for i, n in enumerate(spacy_taggers):
    if n == 'ADJ':
        spacy_taggers[i] = 'ADJF'
    if n == 'ADV':
        spacy_taggers[i] = 'ADVB'
    if n == 'PROPN':
        spacy_taggers[i] = 'NOUN'

# %%
import numpy
import sklearn.metrics

r = sklearn.metrics.confusion_matrix(pos_taggers, spacy_taggers)
r = numpy.flip(r)

acc = (r[0][0] + r[-1][-1]) / numpy.sum(r)
print(acc)
# Out:
# 0.30288461538461536

# %%
# Mystem pos tagger 
mystem_korpus = []
for line in korpus['Word']:
    ana = m.analyze(line)
    mystem_korpus.append(ana)

mystem_korpus[:10]
# Out:
# [[{'analysis': [{'lex': 'ультраженственный',
#      'wt': 0.4541687794,
#      'qual': 'bastard',
#      'gr': 'A=(пр,ед,полн,жен|дат,ед,полн,жен|род,ед,полн,жен|твор,ед,полн,жен)'}],
#    'text': 'ультраженственной'},
#   {'text': '\n'}],
#  [{'analysis': [{'lex': 'миллионометр',
#      'wt': 1,
#      'qual': 'bastard',
#      'gr': 'S,муж,неод=род,ед'}],
#    'text': 'миллионометра'},
#   {'text': '\n'}],
#  [{'analysis': [{'lex': 'гильоше',
#      'wt': 0.2741620489,
#      'qual': 'bastard',
#      'gr': 'S,сред,неод=(пр,мн|пр,ед|вин,мн|вин,ед|дат,мн|дат,ед|род,мн|род,ед|твор,мн|твор,ед|им,мн|им,ед)'}],
#    'text': 'гильоше'},
#   {'text': '\n'}],
#  [{'analysis': [{'lex': 'полуколебание',
#      'wt': 0.5196742212,
#      'qual': 'bastard',
#      'gr': 'S,сред,неод=род,мн'}],
#    'text': 'полуколебаний'},
#   {'text': '\n'}],
#  [{'analysis': [{'lex': 'баухаус',
#      'wt': 1,
#      'qual': 'bastard',
#      'gr': 'S,муж,неод=(вин,ед|им,ед)'}],
#    'text': 'баухаус'},
#   {'text': '\n'}],
#  [{'analysis': [{'lex': 'скелетонный',
#      'wt': 0.8459597832,
#      'qual': 'bastard',
#      'gr': 'A=(пр,мн,полн|вин,мн,полн,од|род,мн,полн)'}],
#    'text': 'скелетонных'},
#   {'text': '\n'}],
#  [{'analysis': [{'lex': 'турбийон',
#      'wt': 0.8054043934,
#      'qual': 'bastard',
#      'gr': 'S,муж,неод=род,ед'}],
#    'text': 'турбийона'},
#   {'text': '\n'}],
#  [{'analysis': [{'lex': 'напылить',
#      'wt': 1,
#      'qual': 'bastard',
#      'gr': 'V,сов,пе=прош,мн,прич,кр,страд'}],
#    'text': 'напылены'},
#   {'text': '\n'}],
#  [{'analysis': [{'lex': 'ультралегкий',
#      'wt': 1,
#      'gr': 'A=(дат,мн,полн|твор,ед,полн,муж|твор,ед,полн,сред)'}],
#    'text': 'ультралегким'},
#   {'text': '\n'}],
#  [{'analysis': [{'lex': 'алмазоподобный',
#      'wt': 1,
#      'gr': 'A,полн=(вин,ед,муж,неод|им,ед,муж)'}],
#    'text': 'алмазоподобный'},
#   {'text': '\n'}]]

# %%
mystem_taggers = []
for word in mystem_korpus:
    if word[0]['analysis'] == []:
        mystem_taggers.append('None')
    else:
        gr = word[0]['analysis'][0]['gr']
        pos = gr.split('=')[0].split(',')[0]
        mystem_taggers.append(pos)

# %%
for i, n in enumerate(mystem_taggers):
    if n == 'A':
        mystem_taggers[i] = 'ADJF'
    if n == 'ADV':
        mystem_taggers[i] = 'ADVB'
    if n == 'S':
        mystem_taggers[i] = 'NOUN'
    if n == 'V':
        mystem_taggers[i] = 'VERB'
    if n == 'PART':
        mystem_taggers[i] = 'PRCL'

# %%
import numpy
import sklearn.metrics

r = sklearn.metrics.confusion_matrix(pos_taggers, mystem_taggers)
r = numpy.flip(r)

acc = (r[0][0] + r[-1][-1]) / numpy.sum(r)
print(acc)
# Out:
# 0.33653846153846156

# %%
# pymorphy pos tagger 
pymorphy_taggers = []
for word in korpus['Word']:
    if morph.parse(word)[0].tag.POS == None:
        pymorphy_taggers.append('None')
    else:
        pymorphy_taggers.append(morph.parse(word)[0].tag.POS)

# %%
import numpy
import sklearn.metrics

r = sklearn.metrics.confusion_matrix(pos_taggers, pymorphy_taggers)
r = numpy.flip(r)

acc = (r[0][0] + r[-1][-1]) / numpy.sum(r)
print(acc)
# Out:
# 0.1971153846153846

# %% [markdown]
# Мы использовали теггеры pymorphy, pymystem и spacy. Из всех трех теггеров accuracy больше всех набрал теггер pymystem. Достоинства Mystem'a: хорошее качество разбора, по умолчанию разрешается частеречная омонимия (внутри части речи остается), при разборе учитывается контекст
# и совместим с разметкой НКРЯ

# %% [markdown]
# # Четвертое задание
#
# Дальше вам нужно взять лучший теггер для русского языка и с его помощью написать функцию (chunker), которая выделяет из размеченного текста 3 типа n-грамм, соответствующих какому-то шаблону (к примеру не + какая-то часть речи или NP или сущ.+ наречие и тд) В предыдущем дз многие из вас справедливо заметили, что если бы мы могли класть в словарь не только отдельные слова, но и словосочетания, то программа работала бы лучше. Предложите 3 шаблона (слово + POS-тег / POS-тег + POS-тег) запись которых в словарь, по вашему мнению, улучшила бы качество работы программы из предыдущей домашки. Балл за объяснение того, почему именно эти группы вы взяли, балл за создание такого рода чанкера, балл за за встраивание функции в программу из предыдущей домашки, балл за сравнение качества предсказания тональности с улучшением и без.

# %%
# возьмем датасет из прошлого домашнего задания, в той тетрадке я сохраняла этот файл и вызывается как selected, он уже есть на гитхабе
selected = pd.read_csv('comments.csv', sep=',')

# %%
#разделим на положительные и отрицательные
positive_df = selected[selected['label_binary'] == 1.0]
negative_df = selected[selected['label_binary'] == 0.0]

# %% [markdown]
# # Функция chunking
# Напишем функцию, которая будет выделять три типа словосочетаний, мы возьмем три шаблона: прилагательные и существительные, глагол и наречие, существительное и существительное. Прилагательное описывает существительное, признак предмета, в нем может содержаться положительная или негативная оценка, наречие тоже описывает признак действия, существительное тоже может иметь негативную или положительную оценку. Так как среди остальных теггеров лучше себя показал теггер pymystem, то используем его в этой функции и вытащим с помощью него части речи. Обязательно будем проверять, есть ли "analysis" в разборе, потому что может и не быть. Проверяем у каждого слова в предложении, есть ли его часть речи в нашем списке ent. Если нету, то добавляем в chunked_sent, а если есть, то смотрим составляет это слова одну из наших шаблонов. После этого добавляем в chunked_sent данные лексемы.

# %%
sent = 'Очень богатый мужчина не дал хорошо мало золотых монет туртсияхх ибиптахучить бедному мальчику'
ent = ("A", "V", "S")
def chunking(sent):
    tagged = []
    chunk = []
    chunked_sent = []
    ana = m.analyze(sent)
    for word in ana:
        if "analysis" in word:
            if word['analysis'] == []:
                chunked_sent.append(word['text'])
            else:
                tagged.append(word['analysis'][0])


    for i, n in enumerate(tagged):
        if i < (len(tagged) - 1):
            if  tagged[i]['gr'].split('=')[0].split(',')[0] not in ent:
                chunked_sent.append(tagged[i]['lex'])
            else:
                if tagged[i]['gr'].split('=')[0].split(',')[0] == "A":
                    if tagged[i+1]['gr'].split('=')[0].split(',')[0] == "S":
                        chunk.append(tagged[i]['lex'])
                        chunk.append(tagged[i+1]['lex'])
                        chunked_sent.append(chunk)
                        chunk = []
                elif tagged[i]['gr'].split('=')[0].split(',')[0] == "V":
                    if tagged[i+1]['gr'].split('=')[0].split(',')[0] == "ADV":
                        chunk.append(tagged[i]['lex'])
                        chunk.append(tagged[i+1]['lex'])
                        chunked_sent.append(chunk)
                        chunk = []
                elif tagged[i]['gr'].split('=')[0].split(',')[0] == "S":
                    if tagged[i+1]['gr'].split('=')[0].split(',')[0] == "S":
                        chunk.append(tagged[i]['lex'])
                        chunk.append(tagged[i+1]['lex'])
                        chunked_sent.append(chunk)
                        chunk = []
    return chunked_sent

# %%
#применим функцию chunking на нашем датасете
positive_tokens = []
for line in positive_df['lemm_clean_tex']:
    positive_tokens.append(chunking(line))

negative_tokens = []
for line in negative_df['lemm_clean_tex']:
    negative_tokens.append(chunking(line))

# %%
positive_tokens
# Out:
# ['некоторые',
#  ['список', 'любовь'],
#  ['герой', 'р'],
#  ['растрелять', 'правда'],
#  'правда',
#  ['воевать', 'недавно'],
#  'недавно',
#  ['неплохой', 'репортаж'],
#  ['наградной', 'лист'],
#  ['лист', 'бой'],
#  ['социалистический', 'родина'],
#  'против',
#  ['немецкий', 'оккупант'],
#  ['решительный', 'командир'],
#  ['наступательный', 'бой'],
#  ['бой', 'район'],
#  ['район', 'моспино'],
#  ['моспино', 'г'],
#  ['г', 'командование'],
#  ['командование', 'полк'],
#  ['полк', 'тов'],
#  ['тов', 'этуш'],
#  ['помощь', 'батальон'],
#  ['сложный', 'обстановка'],
#  ['обстановка', 'выполнение'],
#  ['боевой', 'задача'],
#  ['задача', 'тов'],
#  ['тов', 'этуш'],
#  'бесстрашно',
#  'свой',
#  'смело',
#  ['рота', 'враг'],
#  'чем',
#  'свой',
#  ['умелый', 'маневр'],
#  ['противник', 'район'],
#  ['район', 'городок'],
#  ['солдат', 'офицер'],
#  ['ручной', 'пулемет'],
#  ['большинство', 'сириец'],
#  'который',
#  ['цивилизованный', 'государство'],
#  ['государство', 'весна'],
#  'многий',
#  ['уходить', 'очень'],
#  'очень',
#  'скоро',
#  ['оценка', 'политика'],
#  ['политика', 'аналогия'],
#  'это',
#  ['национальный', 'государство'],
#  ['национальный', 'государство'],
#  ['государство', 'украина'],
#  'именно',
#  ['русский', 'националист'],
#  ['данный', 'случай'],
#  ['случай', 'ополчение'],
#  ['северный', 'кавказ'],
#  ['сторона', 'оппозиция'],
#  'оно',
#  ['усилие', 'штат'],
#  ['штат', 'саудит'],
#  ['потенциальный', 'жертва'],
#  ['жертва', 'теракт'],
#  'поэтому',
#  'очень',
#  ['полный', 'возможность'],
#  ['живой', 'асад'],
#  ['меньшинство', 'житель'],
#  ['житель', 'сирия'],
#  'это',
#  'любой',
#  ['описание', 'событие'],
#  ['событие', 'число'],
#  'совершенно',
#  ['безраличный', 'асад'],
#  ['асад', 'оппозиция'],
#  'он',
#  ['легкий', 'мотоцикл'],
#  ['мотоцикл', 'год'],
#  ['дебил', 'мотик'],
#  ['становиться', 'мало'],
#  'мало',
#  ['здоровый', 'глаз'],
#  ['глаз', 'лоб'],
#  'наш',
#  ['система', 'защита'],
#  ['защита', 'информация'],
#  ['информация', 'государство'],
#  ['государство', 'подруга'],
#  'это',
#  ['расческа', 'барселона'],
#  'точно',
#  ['пригород', 'приз'],
#  ['приз', 'студия'],
#  'либо',
#  'либо',
#  ['хвойный', 'дерево'],
#  'явно',
#  ['юг', 'братислава'],
#  ['братислава', 'барселона'],
#  ['барселона', 'тиран'],
#  ['тиран', 'албания'],
#  'наш',
#  'это',
#  ['испания', 'кастилья'],
#  ['кастилья', 'италия'],
#  ['италия', 'париж'],
#  ['париж', 'прага'],
#  ['прага', 'душанбе'],
#  ['душанбе', 'лиссабон'],
#  ['лиссабон', 'наличие'],
#  ['наличие', 'серп'],
#  ['серп', 'молот'],
#  'однозначно',
#  'это',
#  ['город', 'италия'],
#  ['италия', 'португалия'],
#  ['португалия', 'греция'],
#  ['греция', 'испания'],
#  'мало',
#  ['романоязычный', 'страна'],
#  ['личный', 'состав'],
#  ['состав', 'часовой'],
#  ['часовой', 'пост'],
#  ['пост', 'город'],
#  ['город', 'весна'],
#  ['ворота', 'товарищ'],
#  ['товарищ', 'старшина'],
#  ['старшина', 'товарищ'],
#  ['товарищ', 'старшина'],
#  ['основной', 'рота'],
#  ['адекватный', 'сержант'],
#  ['старослужащий', 'старшина'],
#  'гораздо',
#  'легко',
#  'именно',
#  ['должный', 'образ'],
#  ['рядовой', 'боец'],
#  'всякий',
#  ['классический', 'вариант'],
#  'просто',
#  ['вопрос', 'офицер'],
#  ['докладывать', 'наверное'],
#  'наверное',
#  ['советский', 'устав'],
#  ['устав', 'караульная'],
#  ['гарнизонный', 'служба'],
#  ['служба', 'командир'],
#  ['командир', 'рота'],
#  ['рота', 'зам'],
#  ['зам', 'мочь'],
#  ['день', 'победа'],
#  ['победа', 'праздник'],
#  ['праздник', 'ураа'],
#  ['ураа', 'праздник'],
#  ['праздник', 'победа'],
#  ['победа', 'праздник'],
#  ['праздник', 'праздник'],
#  ['праздник', 'урррррааааа'],
#  ['день', 'победа'],
#  ['победа', 'действитель'],
#  'самый',
#  ['главный', 'праздник'],
#  ['звучать', 'гордо'],
#  'гордо',
#  ['день', 'победа'],
#  ['победа', 'день'],
#  ['день', 'победа'],
#  ['победа', 'праздник'],
#  ['праздник', 'праздник'],
#  ['праздник', 'день'],
#  ['день', 'победа'],
#  ['победа', 'праздник'],
#  ['праздник', 'победа'],
#  ['победа', 'й'],
#  ['й', 'годовщина'],
#  ['годовщина', 'победа'],
#  ['отечественный', 'война'],
#  ['война', 'праздник'],
#  ['праздник', 'день'],
#  ['день', 'победа'],
#  ['победа', 'день'],
#  ['великий', 'победа'],
#  ['победа', 'день'],
#  ['день', 'победа'],
#  ['победа', 'победа'],
#  ['победа', 'день'],
#  ['день', 'победа'],
#  ['победа', 'праздник'],
#  ['настоящий', 'праздник'],
#  'почему',
#  'каждый',
#  ['горький', 'горький'],
#  'мой',
#  'самый',
#  'некуда',
#  ['война', 'праздник'],
#  ['праздник', 'слеза'],
#  ['слеза', 'глаз'],
#  ['глаз', 'урааа'],
#  ['урааа', 'праздник'],
#  ['праздник', 'день'],
#  ['день', 'победа'],
#  ['праздник', 'день'],
#  ['день', 'победа'],
#  'ваш',
#  ['рейтинг', 'топ'],
#  ['судьба', 'запись'],
#  ['запись', 'мочь'],
#  ['мочь', 'ссылка'],
#  'гд',
#  'это',
#  ['точный', 'новость'],
#  'который',
#  'очень',
#  'весьма',
#  'весьма',
#  ['молодец', 'миронов'],
#  ['здравый', 'смысл'],
#  'вновь',
#  ['жизофренять', 'пора'],
#  'пора',
#  'какой',
#  ['политический', 'лагерь'],
#  ['интернет', 'герой'],
#  'два',
#  'такой',
#  'этот',
#  ['сборище', 'большинство'],
#  'свой',
#  ['хороший', 'человек'],
#  'который',
#  'идеалистически',
#  'который',
#  'реально',
#  ['душа', 'россия'],
#  ['россия', 'время'],
#  'такой',
#  ['народ', 'власть'],
#  ['тюрьма', 'исход'],
#  ['исход', 'жизнь'],
#  ['туповатый', 'согражданин'],
#  ['согражданин', 'большинство'],
#  'это',
#  ['личный', 'жизнь'],
#  'свой',
#  ['быдло', 'народ'],
#  ['народ', 'чернь'],
#  'се',
#  'это',
#  ['созыв', 'кс'],
#  'который',
#  'безусловно',
#  'особенно',
#  'определенно',
#  'пусть',
#  'сто',
#  'вполовину',
#  'мало',
#  'хотя',
#  'всякий',
#  ['лимоновый', 'илларионов'],
#  ['илларионов', 'пионтковский'],
#  ['реальный', 'уровень'],
#  ['уровень', 'поддержка'],
#  ['сильный', 'вождь'],
#  ['вождь', 'оппозиция'],
#  ['оппозиция', 'кс'],
#  'особенно',
#  'хотя',
#  'другой',
#  ['политический', 'сила'],
#  ['забывать', 'также'],
#  'также',
#  ['качество', 'площадка'],
#  ['площадка', 'случай'],
#  ['нужный', 'кс'],
#  ['кс', 'курия'],
#  ['курия', 'максимум'],
#  ['максимум', 'представитель'],
#  'бмд',
#  'бмп',
#  'бмп',
#  'бмп',
#  'полнуый',
#  'нпк',
#  ['план', 'м'],
#  ['следующий', 'год'],
#  ['большой', 'завод'],
#  'весь',
#  ['разница', 'рротиворечие'],
#  ['рротиворечие', 'пункт'],
#  'чучуть',
#  'мы',
#  ['нужный', 'гарантия'],
#  ['гарантия', 'оборудование'],
#  'наш',
#  'вообщемто',
#  ['приоритетный', 'доступ'],
#  'он',
#  'хотя',
#  'мы',
#  ['рыбка', 'т'],
#  ['т', 'д'],
#  'мы',
#  ['купить', 'полностью'],
#  'полностью',
#  'наш',
#  ['счет', 'станок'],
#  ['немой', 'изделие'],
#  ['изделие', 'интерес'],
#  ['побочный', 'использование'],
#  ['использование', 'оборудование'],
#  'пожалуйста',
#  'ты',
#  ['треть', 'стоимость'],
#  ['стоимость', 'оборудование'],
#  'весь',
#  'это',
#  ['частный', 'предприятие'],
#  'кстати',
#  'один',
#  'очень',
#  ['гибкий', 'штука'],
#  'никакой',
#  'полностью',
#  ['т', 'д'],
#  ['д', 'авто'],
#  'абсолютно',
#  'точно',
#  'также',
#  ['серобурмалиновый', 'цвет'],
#  'никакой',
#  ['аналог', 'мерс'],
#  ['мерс', 'бмв'],
#  ['бмв', 'волюнтаризм'],
#  ['волюнтаризм', 'покупатель'],
#  'ваш',
#  ['белый', 'цвет'],
#  ['цвет', 'аналог'],
#  ['аналог', 'заказаннойауди'],
#  ['заказаннойауди', 'сторона'],
#  'почемуто',
#  'обязательно',
#  ['заставлянт', 'покупатель'],
#  'либо',
#  ['итог', 'тендер'],
#  'ой',
#  ['оао', 'уралвагонзавод'],
#  ['уралвагонзавод', 'оао'],
#  ['сухой', 'оао'],
#  ['оао', 'туполев'],
#  ['туполев', 'оао'],
#  ['мотовилихинский', 'завод'],
#  ['завод', 'оао'],
#  ['конструкторский', 'бюро'],
#  ['бюро', 'машиностроение'],
#  ['прочий', 'тысяча'],
#  ['ясный', 'перец'],
#  ['перец', 'частник'],
#  'близко',
#  ['больший', 'часть'],
#  ['часть', 'оборонка'],
#  'этот',
#  ['оао', 'зао'],
#  'пусть',
#  ['акция', 'госсобственность'],
#  ['госсобственность', 'капо'],
#  'например',
#  'очень',
#  'именно',
#  'вообще',
#  'часто',
#  ['человеческий', 'мечта'],
#  ['любимый', 'книжка'],
#  ['книжка', 'пасьянс'],
#  'этот',
#  ['жестокий', 'реальность'],
#  'насчет',
#  ['вариант', 'пол'],
#  ['пол', 'удаленка'],
#  ['неделя', 'неделя'],
#  ['неделя', 'офис'],
#  ['офис', 'штат'],
#  'поэтому',
#  ['проект', 'менеджер'],
#  'заодно',
#  ['исполнитель', 'работа'],
#  ['работа', 'проект'],
#  ['проект', 'т'],
#  ['т', 'е'],
#  ['е', 'исполнитель'],
#  ['исполнитель', 'подчинение'],
#  'понятно',
#  'изначально',
#  ['построить', 'правильно'],
#  'правильно',
#  'именно',
#  'тот',
#  ['оперативный', 'работа'],
#  ['работа', 'дом'],
#  ['личный', 'производительность'],
#  ['производительность', 'план'],
#  ['план', 'выполнение'],
#  ['выполнение', 'оперативка'],
#  ['высокий', 'работа'],
#  ['работа', 'офис'],
#  'мало',
#  ['неизбежный', 'перерыв'],
#  ['перерыв', 'работа'],
#  ['домашний', 'дело'],
#  ['дело', 'план'],
#  ['план', 'контроль'],
#  ['контроль', 'работа'],
#  ['работа', 'исполнитель'],
#  'главное',
#  ['волна', 'неделя'],
#  ['рабочий', 'ритм'],
#  ['четкий', 'планирование'],
#  ['планирование', 'задача'],
#  ['задача', 'время'],
#  ['время', 'понимание'],
#  ['понимание', 'ответственность'],
#  ['ответственность', 'невыполнение'],
#  'это',
#  ['личный', 'опыт'],
#  'постоянно',
#  'хотя',
#  ['артем', 'горбунов'],
#  'тот',
#  'один',
#  'кстати',
#  ['описание', 'ресурс'],
#  ['ресурс', 'ссылка'],
#  'который',
#  ['привлечение', 'команда'],
#  ['правильный', 'человек'],
#  'это',
#  ['стартаповский', 'подход'],
#  ['подход', 'деньги'],
#  ['кончаться', 'рано'],
#  'рано',
#  'очевидно',
#  'хотя',
#  'тот',
#  ['пас', 'коровенка'],
#  ['коровенка', 'корова'],
#  ['корова', 'деревня'],
#  ['деревня', 'жизнь'],
#  ['жизнь', 'корова'],
#  'такой',
#  'такой',
#  ['страшный', 'рог'],
#  ['рог', 'ужас'],
#  'все',
#  'свой',
#  ['маленький', 'хозяйство'],
#  'оно',
#  ['корова', 'зорька'],
#  ['зорька', 'корова'],
#  ['страшный', 'зверь'],
#  ['опасаться', 'тож'],
#  'тож',
#  ['корова', 'молоко'],
#  ['детство', 'деревня'],
#  ['деревня', 'корова'],
#  'такой',
#  ['ответственный', 'дело'],
#  'ь',
#  'ь',
#  ['праздник', 'ч'],
#  ['ч', 'сан'],
#  ['сан', 'день'],
#  ['день', 'победа'],
#  'самый',
#  ['ьем', 'ус'],
#  ['ус', 'м'],
#  ['м', 'праздник'],
#  ['праздник', 'праздник'],
#  ['светлый', 'память'],
#  'все',
#  ['победа', 'праздник'],
#  ['праздник', 'праздник'],
#  ['праздник', 'день'],
#  ['день', 'победа'],
#  ['вечный', 'память'],
#  ['память', 'герой'],
#  ['герой', 'день'],
#  ['день', 'победа'],
#  ['великий', 'праздник'],
#  ['праздник', 'день'],
#  ['день', 'победа'],
#  ['победа', 'день'],
#  ['день', 'победа'],
#  ['победа', 'день'],
#  ['день', 'победа'],
#  ['победа', 'мир'],
#  ['мир', 'счастие'],
#  ['счастие', 'благополучие'],
#  'весь',
#  'мы',
#  'ура',
#  ['праздник', 'праздник'],
#  ['праздник', 'мир'],
#  ['мир', 'любовь'],
#  ['любовь', 'оксана'],
#  ['оксана', 'праздник'],
#  'ко',
#  ['френдмарафон', 'привет'],
#  ['привет', 'день'],
#  ['день', 'победа'],
#  ['победа', 'победа'],
#  ['победа', 'мочь'],
#  ['мочь', 'политика'],
#  ['политика', 'день'],
#  ['день', 'победа'],
#  ['победа', 'спасибо'],
#  ['спасибо', 'праздник'],
#  ['праздник', 'слава'],
#  ['бог', 'война'],
#  ['война', 'праздник'],
#  ['праздник', 'спасибо'],
#  ['спасибо', 'малик'],
#  ['великий', 'победа'],
#  'это',
#  ['политика', 'политика'],
#  ['политика', 'ссср'],
#  ['ссср', 'политика'],
#  ['честный', 'гражданин'],
#  ['гражданин', 'ссср'],
#  'весь',
#  'второй',
#  ['мировой', 'война'],
#  ['война', 'слово'],
#  ['слово', 'политика'],
#  ['грязный', 'слово'],
#  'оттого',
#  ['опошлять', 'нынче'],
#  'нынче',
#  'это',
#  ['политика', 'ссср'],
#  'второй',
#  ['мировой', 'война'],
#  'трудно',
#  ['смотреть', 'правда'],
#  'правда',
#  ['розовый', 'очки'],
#  ['фото', 'глаз'],
#  ['глаз', 'спасибо'],
#  'взаимно',
#  ['день', 'победа'],
#  'ничто',
#  'спасибочки',
#  'взаимно',
#  ['спасибо', 'праздник'],
#  ['вечный', 'память'],
#  'наверное',
#  ['праздник', 'праздник'],
#  'взаимно',
#  'взаимно',
#  'мой',
#  'свой',
#  ['спасибо', 'победа'],
#  ['вечный', 'память'],
#  ['память', 'герой'],
#  'взаимно',
#  ['праздник', 'праздник'],
#  ['праздник', 'праздник'],
#  ['праздник', 'победа'],
#  ['победа', 'дед'],
#  ['дед', 'отец'],
#  'сто',
#  ['грамм', 'победа'],
#  ['победа', 'спасибо'],
#  'взаимно',
#  ['спасибо', 'женечка'],
#  ['женечка', 'победа'],
#  ['победа', 'спасибо'],
#  'ервой',
#  'вай',
#  'столько',
#  'чу',
#  'чу',
#  'взаимно',
#  ['день', 'победа'],
#  'взаимно',
#  ['победа', 'праздник'],
#  ['праздник', 'победа'],
#  ['победа', 'спасибо'],
#  ['спасибо', 'праздник'],
#  ['праздник', 'победа'],
#  ['победа', 'победа'],
#  ['победа', 'праздник'],
#  ['праздник', 'победа'],
#  ['мариямполе', 'алитус'],
#  ['полсотни', 'пост'],
#  'это',
#  'отлично',
#  'сегодня',
#  ['скромный', 'калининград'],
#  ['калининград', 'фотосъемка'],
#  ['запрещать', 'вполне'],
#  'вполне',
#  'неплохо',
#  'ах',
#  ['паланга', 'студент'],
#  ['студент', 'калининград'],
#  'это',
#  'весьма',
#  ['романтичный', 'место'],
#  ['место', 'поездка'],
#  ['клевета', 'кениг'],
#  'давно',
#  ['й', 'форт'],
#  'благодаря',
#  'еще',
#  ['й', 'й'],
#  'второй',
#  'хотя',
#  ['е', 'год'],
#  ['год', 'паланга'],
#  'нлп',
#  ['господин', 'ашурков'],
#  ['полный', 'право'],
#  ['финансовый', 'отчет'],
#  ['денежный', 'средство'],
#  ['средство', 'средство'],
#  ['быть', 'далее'],
#  'далее',
#  ['решать', 'ответственно'],
#  'ответственно',
#  'свой',
#  ['избранный', 'член'],
#  ['член', 'кс'],
#  ['кс', 'ирония'],
#  ['ирония', 'большинство'],
#  ['большинство', 'член'],
#  ['член', 'ксо'],
#  ['ксо', 'агент'],
#  ['агент', 'встраивание'],
#  ['встраивание', 'оппозиция'],
#  ['системный', 'политика'],
#  'худо',
#  'бедно',
#  'свой',
#  ['определенный', 'количество'],
#  ['количество', 'гражданин'],
#  ['член', 'генсовет'],
#  ['единый', 'россия'],
#  ['россия', 'владимир'],
#  ['владимир', 'бурмат'],
#  'этот',
#  'вчера',
#  'свой',
#  ['представлять', 'скоро'],
#  'скоро',
#  ['немой', 'концепция'],
#  'это',
#  'просто',
#  'феноменально',
#  'четко',
#  ['офмцмальный', 'позиция'],
#  'относительно',
#  ['кс', 'кс'],
#  ['концепция', 'протопарламент'],
#  ['задача', 'создание'],
#  ['региональный', 'ксов'],
#  'весь',
#  ['территория', 'россия'],
#  ['потенциальный', 'источник'],
#  ['альтернативный', 'легитимность'],
#  'совершенно',
#  'недопустимо',
#  ['кс', 'проект'],
#  ['проект', 'организация'],
#  ['карманный', 'оппозиция'],
#  'благодаря',
#  ['республиканский', 'фракция'],
#  'все',
#  'понятно',
#  ['огромный', 'степень'],
#  'благодаря',
#  ['последовательный', 'деятельность'],
#  ['деятельность', 'направление'],
#  ['направление', 'хозяин'],
#  ['хозяин', 'блог'],
#  ['блог', 'кс'],
#  ['возможный', 'модель'],
#  ['модель', 'организация'],
#  ['протестный', 'движение'],
#  'весь',
#  'это',
#  'хотя',
#  'вполне',
#  'этот',
#  ['митинг', 'песня'],
#  ['молодой', 'человек'],
#  'это',
#  ['глубинный', 'результат'],
#  ['сказываться', 'возможно'],
#  'возможно',
#  'скоро',
#  ['потенциал', 'кс'],
#  'очень',
#  'быстро',
#  'лгбт',
#  'разумеется',
#  ['российский', 'обскурантизм'],
#  ['обскурантизм', 'дикость'],
#  ['православнутый', 'архаика'],
#  ['архаика', 'латиноамериканец'],
#  ['стоять', 'впереди'],
#  'впереди',
#  ['спорить', 'кажется'],
#  'кажется',
#  ['коммунизм', 'учение'],
#  ['учение', 'христос'],
#  'это',
#  ['конечный', 'счет'],
#  'один',
#  ['различный', 'слово'],
#  ['слово', 'коммунизм'],
#  'столько',
#  ['экономический', 'формация'],
#  'первый',
#  'духовно',
#  ['нравственный', 'состояние'],
#  ['состояние', 'общество'],
#  ['коммунистический', 'формация'],
#  ['коммунистический', 'способ'],
#  ['способ', 'производство'],
#  ['духовный', 'перестройка'],
#  ['перестройка', 'человечество'],
#  ['человечество', 'основа'],
#  'который',
#  'сначала',
#  'другой',
#  ['последний', 'очередь'],
#  ['очередь', 'забота'],
#  'это',
#  'столь',
#  ['настоящий', 'коммунар'],
#  ['коммунар', 'призыв'],
#  ['призыв', 'христос'],
#  ['христос', 'аскетизм'],
#  ['аскетизм', 'искоренение'],
#  ['искоренение', 'жажда'],
#  'благо',
#  ['признание', 'уважение'],
#  ['уважение', 'общество'],
#  ['общество', 'известность'],
#  ['известность', 'слава'],
#  ['слава', 'статус'],
#  ['статус', 'место'],
#  ['общественный', 'иерархия'],
#  ['иерархия', 'коммунизм'],
#  ['критерий', 'истина'],
#  'это',
#  ['практика', 'чавес'],
#  'публично',
#  ['серебряный', 'крестик'],
#  ['крестик', 'средневековье'],
#  ['российский', 'левак'],
#  ['православнутый', 'архаика'],
#  ['архаика', 'тысяча'],
#  ['магкоев', 'десяток'],
#  'нтр',
#  'эффективно',
#  ['земной', 'альянс'],
#  ['альянс', 'сообщество'],
#  ['сообщество', 'конгломерат'],
#  ['разный', 'страна'],
#  'внутри',
#  ['культурный', 'особенность'],
#  ['особенность', 'граница'],
#  ['граница', 'барьер'],
#  'мало',
#  'один',
#  'другой',
#  'просто',
#  ['автоматический', 'система'],
#  ['система', 'перевод'],
#  'близко',
#  ['друг', 'друг'],
#  'социально',
#  ['экономический', 'модель'],
#  ['модель', 'альянс'],
#  'естественно',
#  'причем',
#  ['красный', 'цвет'],
#  ['цвет', 'православие'],
#  ['православие', 'самодержавие'],
#  ['самодержавие', 'народностьперестройка'],
#  ['народностьперестройка', 'приватизация'],
#  ['хороший', 'император'],
#  ['император', 'позор'],
#  ['плохой', 'боярин'],
#  ['боярин', 'империя'],
#  'любой',
#  ['империя', 'протяжение'],
#  'весь',
#  ['история', 'человечество'],
#  'этот',
#  'один',
#  ['национальный', 'большинство'],
#  'менее',
#  'другой',
#  ['национальный', 'меньшинство'],
#  ['меньшинство', 'класс'],
#  ['ссср', 'империя'],
#  'серо',
#  'еще',
#  'какой',
#  'верно',
#  'поскольку',
#  'это',
#  ['социалистический', 'республика'],
#  ['социалистический', 'т'],
#  ['т', 'е'],
#  'такой',
#  ['законодательный', 'уровень'],
#  ['принцип', 'запрет'],
#  'любой',
#  ['форма', 'эксплуатация'],
#  ['эксплуатация', 'угнетение'],
#  ['угнетение', 'форма'],
#  ['форма', 'деятельность'],
#  ['деятельность', 'государство'],
#  ['развитие', 'социализация'],
#  ['социализация', 'личность'],
#  ['принудительный', 'порядок'],
#  ['привет', 'дебют'],
#  'давно',
#  'это',
#  'действительно',
#  'намного',
#  'дешево',
#  'раз',
#  'быстро',
#  'ежели',
#  ['пеший', 'поход'],
#  ['поход', 'время'],
#  'недавно',
#  ['купон', 'скидка'],
#  'очень',
#  'выгодно',
#  ['найсер', 'дайсер'],
#  ['дайсер', 'кухня'],
#  ['часовой', 'страдание'],
#  ['страдание', 'турция'],
#  ['пляжный', 'отдых'],
#  'давно',
#  'просто',
#  ['сарделька', 'море'],
#  'этот',
#  ['местный', 'менталитет'],
#  ['менталитет', 'хватание'],
#  ['хватание', 'рука'],
#  ['рука', 'т'],
#  ['т', 'п'],
#  'возможно',
#  ['год', 'жизнь'],
#  ['жизнь', 'кипр'],
#  'мой',
#  ['сознание', 'отпечаток'],
#  ['отпечаток', 'стамбул'],
#  'такой',
#  'довольно',
#  'свежо',
#  'особенно',
#  'оба',
#  ['лайнер', 'компания'],
#  'другой',
#  'дешево',
#  'такой',
#  ['саутгемптон', 'кобх'],
#  ['кобх', 'ирландия'],
#  ['ирландия', 'дублин'],
#  ['дублин', 'ливерпуль'],
#  ['ливерпуль', 'глазго'],
#  ['глазго', 'белфаст'],
#  ['белфаст', 'инвергордон'],
#  ['инвергордон', 'эдинбург'],
#  ['эдинбург', 'гавр'],
#  'почему',
#  ['руан', 'день'],
#  'боязно',
#  ['нестандартный', 'вид'],
#  ['вид', 'путешествие'],
#  ['путешествие', 'вероятность'],
#  ['вероятность', 'шторм'],
#  'очень',
#  'каждый',
#  'другой',
#  'туда',
#  ['теплый', 'время'],
#  ['время', 'год'],
#  'боязно',
#  ['билет', 'кораблик'],
#  'это',
#  ['полюбоваться', 'очень'],
#  'очень',
#  ['чехия', 'наметка'],
#  'давно',
#  ['прага', 'замок'],
#  'никак',
#  ['дело', 'вкус'],
#  ['вкус', 'статистика'],
#  'честно',
#  'оба',
#  ['круиз', 'длительность'],
#  ['длительность', 'неделя'],
#  'каждый',
#  'лишь',
#  ['неспокойный', 'море'],
#  ['море', 'британия'],
#  ['британия', 'лайнер'],
#  'слегка',
#  ['покачиваться', 'немного'],
#  'немного',
#  'мутно',
#  ['ходить', 'невозможно'],
#  'невозможно',
#  'такой',
#  'который',
#  ['настоящий', 'махина'],
#  ['махина', 'палуба'],
#  ['палуба', 'высота'],
#  ['большой', 'дом'],
#  ['дом', 'время'],
#  ['время', 'плавание'],
#  ['плавание', 'шторм'],
#  ['ощущаться', 'сухо'],
#  'самый',
#  ['декларация', 'образование'],
#  ['образование', 'ссср'],
#  ['причина', 'путь'],
#  ['путь', 'решение'],
#  ['решение', 'проблема'],
#  ['проблема', 'время'],
#  ['время', 'образование'],
#  ['советский', 'республика'],
#  ['республика', 'государство'],
#  ['государство', 'мир'],
#  ['лагерь', 'лагерь'],
#  ['лагерь', 'капитализм'],
#  ['капитализм', 'лагерь'],
#  ['лагерь', 'социализм'],
#  ['социализм', 'лагерь'],
#  ['лагерь', 'капитализм'],
#  ['национальный', 'вражда'],
#  ['вражда', 'неравенство'],
#  ['колониальный', 'рабство'],
#  ['рабство', 'шовинизм'],
#  ['национальный', 'угнетение'],
#  ['угнетение', 'погром'],
#  ['империалистический', 'зверство'],
#  ['зверство', 'война'],
#  ['война', 'лагерь'],
#  ['лагерь', 'социализм'],
#  ['взаимный', 'доверие'],
#  ['доверие', 'мир'],
#  ['национальный', 'свобода'],
#  ['свобода', 'равенство'],
#  ['мирный', 'сожительство'],
#  ['братский', 'сотрудничество'],
#  ['сотрудничество', 'народ'],
#  ['народ', 'попытка'],
#  ['капиталистический', 'мир'],
#  ['мир', 'протяжение'],
#  ['протяжение', 'десяток'],
#  ['десяток', 'год'],
#  ['вопрос', 'национальность'],
#  'путем',
#  ['свободный', 'развитие'],
#  ['развитие', 'народ'],
#  ['народ', 'система'],
#  ['система', 'эксплуатация'],
#  ['эксплуатация', 'человек'],
#  ['человек', 'человек'],
#  'наоборот',
#  ['национальный', 'противоречие'],
#  'самый',
#  ['существование', 'капитализм'],
#  ['капитализм', 'буржуазия'],
#  ['сотрудничество', 'народ'],
#  ['народ', 'лагерь'],
#  ['лагерь', 'совет'],
#  ['совет', 'условие'],
#  ['условие', 'диктатура'],
#  ['диктатура', 'пролетариат'],
#  'вокруг',
#  ['большинство', 'население'],
#  ['национальный', 'гнет'],
#  ['взаимный', 'доверие'],
#  ['братский', 'сотрудничество'],
#  ['сотрудничество', 'народ'],
#  'бмп',
#  'бмп',
#  ...]

# %%
import operator
from functools import reduce
positive_tokens = reduce(operator.concat, positive_tokens)
negative_tokens = reduce(operator.concat, negative_tokens)

# %%
positive_tuple = []
for i in positive_tokens:
    if type(i) is list:
        positive_tuple.append(tuple(i))
    else:
        positive_tuple.append(i)

negative_tuple = []
for i in negative_tokens:
    if type(i) is list:
        negative_tuple.append(tuple(i))
    else:
        negative_tuple.append(i)

# %%
#Возвращает словарь {слово: абсолютная частота встречаемости} на основе списка слов positive_tokens
pos_freq = {}
for pos_word in positive_tuple:
    if pos_word in pos_freq:
        pos_freq[pos_word] += 1
    else:
        pos_freq[pos_word] = 1

neg_freq = {}
for neg_word in negative_tuple:
    if neg_word in neg_freq:
        neg_freq[neg_word] += 1
    else:
        neg_freq[neg_word] = 1

# %%
#выбросим слова, которые встречаются только 1-2 раза
pos_words = []
for pos_word, freq_word in pos_freq.items():
    if freq_word > 2:
        pos_words.append(pos_word)

neg_words = []
for neg_word, freq_word in neg_freq.items():
    if freq_word > 2:
        neg_words.append(neg_word)

# %%
pos_set = set(pos_words)
neg_set = set(neg_words)

# %%
diff_pos = pos_set.difference(neg_set)
diff_neg = neg_set.difference(pos_set)

# %%
diff_pos = pos_set.difference(neg_set)
diff_neg = neg_set.difference(pos_set)
print(diff_pos)
print(diff_neg)
# Out:
# {('этри', 'хшир'), ('форма', 'вулкан'), ('поток', 'человек'), ('дело', 'женщина'), ('режим', 'труд'), ('магазин', 'отличие'), ('английский', 'отличница'), ('ток', 'будущее'), ('большой', 'сила'), ('оптимальный', 'лечение'), ('печать', 'страница'), ('всяческий', 'лытдыбров'), ('помесь', 'храм'), ('область', 'простор'), ('сильный', 'дед'), ('своеобразный', 'проявление'), ('местный', 'красотка'), ('горячий', 'война'), ('национальный', 'наряд'), ('новый', 'танк'), ('единичный', 'деталь'), ('сладкий', 'финик'), ('запись', 'герой'), ('класс', 'молодчинка'), ('офисный', 'труд'), ('французский', 'савойя'), ('ребенок', 'кредит'), ('подвиг', 'герой'), ('ребенок', 'хатынипесняр'), 'звр', ('работа', 'принцип'), ('контекст', 'год'), ('удобный', 'палатка'), ('день', 'джип'), ('конец', 'тропа'), ('время', 'идея'), ('аналогичный', 'впечатление'), ('голландия', 'ряд'), ('обида', 'женщина'), ('работа', 'китай'), ('формулировка', 'десяток'), ('привет', 'аня'), ('настоящий', 'пользователь'), ('канада', 'хотелок'), ('ванильный', 'баранка'), ('история', 'праздник'), ('отпечаток', 'реакция'), ('настоящий', 'контекст'), ('нормальный', 'секс'), ('обычный', 'день'), ('работать', 'дома'), ('дело', 'рф'), ('тэтчер', 'пользователь'), ('м', 'сентябрь'), ('старый', 'выключатель'), ('гастрарбайтер', 'фрилансер'), ('многолюдный', 'девушка'), ('хороший', 'хокон'), ('спасибо', 'репортаж'), ('префектура', 'свао'), ('тэтчер', 'контекст'), ('чело', 'кафель'), ('утро', 'мечта'), ('священый', 'трепет'), ('ощущение', 'турист'), ('крылатка', 'маргарет'), ('гудение', 'провод'), ('смотреть', 'правда'), ('кутузов', 'георгий'), ('хрен', 'знать'), ('город', 'кремль'), ('итог', 'девочка'), ('память', 'дракино'), ('губернатор', 'техас'), 'нечно', ('чукотский', 'девушка'), ('здание', 'завод'), ('отличный', 'орех'), ('постапокалиптический', 'девайса'), ('доверие', 'нация'), ('пыльный', 'дорога'), ('место', 'дорога'), ('индия', 'вьетнам'), ('белевский', 'пастила'), ('рожать', 'имхо'), ('клубника', 'тарелочка'), 'мч', ('ребята', 'божен'), ('туристический', 'точка'), ('новый', 'победа'), ('спасибо', 'майя'), ('профессор', 'промышленник'), ('цистерна', 'вино'), ('корова', 'вечер'), ('часть', 'удар'), ('рынок', 'выходной'), ('молодец', 'день'), ('род', 'озноб'), ('россия', 'белоруссия'), ('модель', 'поведение'), ('дикторша', 'мозг'), ('непьющий', 'улыбка'), ('красный', 'коммунист'), ('пожилой', 'представитель'), ('вдв', 'день'), ('богатый', 'женщина'), ('бесценный', 'опыт'), ('европа', 'защита'), ('настоящий', 'сказка'), ('доминиканский', 'ром'), ('застройка', 'поле'), 'гипотетически', ('уважение', 'человек'), ('испытывать', 'непосредственно'), ('озноб', 'кесарев'), ('спасибо', 'олег'), ('фото', 'стих'), ('колорит', 'спешка'), ('обычный', 'жизнь'), ('муж', 'повар'), ('сплошной', 'счастие'), ('маргарита', 'ром'), ('залоговый', 'цена'), ('деньги', 'дурак'), ('грецкий', 'орех'), ('французский', 'колония'), ('оплот', 'мечта'), ('ситуация', 'поднятие'), ('государственный', 'образец'), ('френдесса', 'приз'), ('пардон', 'генуэзец'), ('яркий', 'небо'), ('одуван', 'конспирология'), ('военный', 'письмо'), ('помнить', 'похоже'), ('общепринятый', 'жест'), ('память', 'хатынь'), ('корейский', 'японец'), ('привязанность', 'москва'), ('древний', 'тайна'), ('кровь', 'эндорфин'), ('шенгенский', 'зона'), ('королевский', 'династия'), ('спорт', 'шпорт'), ('ярмон', 'страна'), ('гуманитарный', 'дисциплина'), ('махмуд', 'респект'), ('атеист', 'глубина'), ('срочный', 'лев'), ('съедобный', 'флорида'), ('украина', 'кавказ'), ('потуга', 'жар'), ('х', 'машина'), ('сделать', 'вместе'), ('игнор', 'украшение'), ('марихуана', 'доказательство'), ('человек', 'семья'), ('траблов', 'человек'), ('взгляд', 'вау'), ('бразда', 'правление'), ('работа', 'сайт'), ('индия', 'индия'), ('факультативный', 'протокол'), ('москвич', 'деньги'), ('малолетний', 'карапуз'), ('вид', 'зависть'), ('удача', 'голова'), ('город', 'ссср'), ('людской', 'агрессия'), ('рожать', 'быстро'), ('выставка', 'картина'), ('рог', 'ужас'), ('печать', 'вые ...
# {('пошлость', 'засилье'), ('следующий', 'пробка'), ('российский', 'товар'), ('есо', 'ебнутыйнах'), ('директор', 'фсб'), ('частный', 'центро'), ('нужный', 'программа'), ('куча', 'мудак'), ('стена', 'путин'), ('уличный', 'контейнер'), 'позади', ('риторика', 'партия'), ('бремяна', 'горло'), ('семья', 'вопрос'), ('железный', 'палочка'), ('мусульманин', 'ислам'), ('защита', 'транспорт'), ('больший', 'преступник'), ('спарринг', 'москва'), ('нужный', 'разгон'), 'безнаказанно', ('черный', 'индиец'), ('общий', 'целое'), ('повод', 'огонь'), ('колоссальный', 'заряд'), ('воронеж', 'замок'), ('слух', 'дело'), ('наличие', 'последствие'), ('направление', 'виселица'), ('жирный', 'мва'), ('сторона', 'лето'), ('год', 'срок'), ('халявный', 'кормушка'), ('сильный', 'рука'), ('липовый', 'затрата'), ('стрелять', 'достаточно'), ('уполномоченный', 'гос'), ('боевой', 'пловец'), ('курить', 'вполне'), ('ясаковый', 'галина'), 'принудительно', 'срутся', ('недостающий', 'сумма'), ('следующий', 'генсек'), ('колорадский', 'жук'), ('красота', 'экологичность'), ('министр', 'здравоохранение'), ('отношение', 'израиль'), ('больница', 'село'), ('случай', 'рентабельность'), 'шестнадцатый', ('разница', 'араб'), ('строгость', 'наказание'), ('мегафон', 'втб'), ('перепост', 'материал'), ('спамерский', 'аккаунт'), ('средство', 'счет'), ('лютый', 'пиздец'), ('малиновский', 'строительство'), ('чартер', 'челябинск'), ('лидерский', 'качество'), ('вуз', 'подтверждение'), ('танк', 'т'), ('структура', 'оружие'), ('херня', 'мелочь'), ('долговой', 'расписка'), ('ясный', 'подонок'), ('заболевание', 'мозг'), ('пофиг', 'пидарюга'), ('ожесточенный', 'перестрелка'), ('либеральный', 'толк'), ('черный', 'химия'), ('правитель', 'россия'), ('красный', 'дорога'), ('лихтенштейн', 'еэз'), ('проклятый', 'ельцин'), ('лиахвский', 'ущелие'), ('дуга', 'больная'), ('сказка', 'процент'), 'низкй', ('миллион', 'баран'), ('человек', 'нож'), ('управляющий', 'жэкад'), ('мочь', 'совесть'), ('готовый', 'раб'), ('таракан', 'триумф'), ('госдеповский', 'выкормыш'), ('окоп', 'ватник'), ('нужный', 'человек'), ('грузинский', 'солдат'), ('гуманист', 'океан'), ('народ', 'человек'), ('совершеннолетняя', 'общество'), ('одинокий', 'девушка'), ('бюрократ', 'пример'), ('ск', 'мвд'), ('судно', 'россия'), ('москвич', 'падла'), ('казачий', 'полк'), ('военный', 'причина'), ('грамофон', 'чантурия'), ('писать', 'возможно'), ('скандал', 'гламур'), ('рафик', 'неуыновный'), ('дед', 'петр'), ('россия', 'азарова'), ('очередной', 'фикция'), ('признак', 'несостоятельность'), ('точный', 'количество'), ('аллергия', 'дух'), ('мнеденьги', 'содержание'), ('изображать', 'однажды'), ('бездельник', 'уебанов'), ('избирательный', 'право'), ('энергетический', 'брешь'), ('переклеивание', 'этикеточка'), ('работа', 'китаец'), ('сарафан', 'ябное'), ('нюни', 'произвол'), ('русло', 'ссср'), ('мусор', 'улица'), 'пятнадцать', ('вопрос', 'начальник'), ('революция', 'лимон'), ('правильный', 'революция'), ('штирлиц', 'еврей'), ('чистый', 'совесть'), ('измайловский', 'полк'), ('гражданский', 'мужество'), ('судебный', 'решение'), ('хороший', 'писатель'), 'вдобавок', ('анализ', 'неравенство'), ('андрей', 'платонов'), ('большой', 'разум'), ('реклама', 'товар'), ('сторона', 'народ'), ('сраный', 'роиссе'), ('отказ', 'г'), ('результат', 'следствие'), ('история', 'страна'), ('ребенок', 'ювеналка'), ('казачий', 'организация'), ('цель', 'воздействие'), ('преступление', 'момент'), ('телефонный', 'звонок'), 'воворемя', ('единственный', 'человек'), ('венерический', 'заболевание'), ('деталь', 'тз'), 'девяностый', ('рассуждение', 'маркс'), ('дом', 'ске'), ('мудрый', 'наставник'), ('президиум', 'ран'), ('мусульманин', 'конституция'), ('эффект', 'синька'), ('закалка', 'пациент'), ('малый', 'родина'), ('экг', 'запись'), ('ом', 'тема'), ('доблестный', 'опера'), ('ольхон', 'остров'), ('хреновый', 'пустыня'), ('правый', 'милосердие'), ('правосудие', 'гарант'), ('скотенков', 'сурков'), ('специальный', 'лагерь'), ('сторонник', 'даосизм'), ('счетный', 'палата'), ('спиртной', ...

# %% [markdown]
# Возьмем функцию из прошлого домашнего задания и немного ее переделаем под наше задание, используем в ней нашу функцию chunking и списки заменим на кортежи.

# %%
def sentiment_analysis(reply):
    clear_text = re.sub(r'[^А-яЁё]+', ' ', text).lower()
    lemmas = m.lemmatize(clear_text)
    lemm_text = ''.join(lemmas)
    tokens = word_tokenize(lemm_text)
    joined_tokens= ' '.join(tokens)
    chunked = chunking(joined_tokens)
    sent_tuple = []
    for i in chunked:
        if type(i) is list:
            sent_tuple.append(tuple(i))
        else:
            sent_tuple.append(i)

    sample_set = set(tokens)
    if sample_set.intersection(diff_pos) > sample_set.intersection(diff_neg):
        print('positive')
    else:
        print('negative')

# %%
#вытащим первые пять положительных и отрицательных комментариев, чтобы проверить функцию и рассчитать accuracy
scrapped = {}
for line in positive_df['text'].head():
    scrapped[line] = "positive"

for line in negative_df['text'].head():
    scrapped[line] = "negative"

# %%
y_true = list(scrapped.values())
scrapped_keys = list(scrapped.keys())

# %%
b = []
def sentiment_analysis(reply):
    clear_text = re.sub(r'[^А-яЁё]+', ' ', text).lower()
    lemmas = m.lemmatize(clear_text)
    lemm_text = ''.join(lemmas)
    tokens = word_tokenize(lemm_text)
    joined_tokens= ' '.join(tokens)
    chunked = chunking(joined_tokens)
    sent_tuple = []
    for i in chunked:
        if type(i) is list:
            sent_tuple.append(tuple(i))
        else:
            sent_tuple.append(i)

    sample_set = set(tokens)
    if sample_set.intersection(diff_pos) > sample_set.intersection(diff_neg):
        b.append('positive')
    else:
        b.append('negative')
    return b

# %%
for key in scrapped_keys:
    y_pred = sentiment_analysis(key)

# %%
import numpy
import sklearn.metrics


r = sklearn.metrics.confusion_matrix(y_true, y_pred)
r = numpy.flip(r)

acc = (r[0][0] + r[-1][-1]) / numpy.sum(r)
print(acc)
# Out:
# 0.5

# %% [markdown]
# Получаем, что accuracy равно 0.5 как и было в прошлом задании. Также можем взять NLTK VADER и с помощью него, разделить слова и словосочетания в нашем словаре на положительные, нейтральные и отрицательные.

# %%
extraPhrase = positive_tokens + negative_tokens
extraPhrase
# Out:
# ['некоторые',
#  ['список', 'любовь'],
#  ['герой', 'р'],
#  ['растрелять', 'правда'],
#  'правда',
#  ['воевать', 'недавно'],
#  'недавно',
#  ['неплохой', 'репортаж'],
#  ['наградной', 'лист'],
#  ['лист', 'бой'],
#  ['социалистический', 'родина'],
#  'против',
#  ['немецкий', 'оккупант'],
#  ['решительный', 'командир'],
#  ['наступательный', 'бой'],
#  ['бой', 'район'],
#  ['район', 'моспино'],
#  ['моспино', 'г'],
#  ['г', 'командование'],
#  ['командование', 'полк'],
#  ['полк', 'тов'],
#  ['тов', 'этуш'],
#  ['помощь', 'батальон'],
#  ['сложный', 'обстановка'],
#  ['обстановка', 'выполнение'],
#  ['боевой', 'задача'],
#  ['задача', 'тов'],
#  ['тов', 'этуш'],
#  'бесстрашно',
#  'свой',
#  'смело',
#  ['рота', 'враг'],
#  'чем',
#  'свой',
#  ['умелый', 'маневр'],
#  ['противник', 'район'],
#  ['район', 'городок'],
#  ['солдат', 'офицер'],
#  ['ручной', 'пулемет'],
#  ['большинство', 'сириец'],
#  'который',
#  ['цивилизованный', 'государство'],
#  ['государство', 'весна'],
#  'многий',
#  ['уходить', 'очень'],
#  'очень',
#  'скоро',
#  ['оценка', 'политика'],
#  ['политика', 'аналогия'],
#  'это',
#  ['национальный', 'государство'],
#  ['национальный', 'государство'],
#  ['государство', 'украина'],
#  'именно',
#  ['русский', 'националист'],
#  ['данный', 'случай'],
#  ['случай', 'ополчение'],
#  ['северный', 'кавказ'],
#  ['сторона', 'оппозиция'],
#  'оно',
#  ['усилие', 'штат'],
#  ['штат', 'саудит'],
#  ['потенциальный', 'жертва'],
#  ['жертва', 'теракт'],
#  'поэтому',
#  'очень',
#  ['полный', 'возможность'],
#  ['живой', 'асад'],
#  ['меньшинство', 'житель'],
#  ['житель', 'сирия'],
#  'это',
#  'любой',
#  ['описание', 'событие'],
#  ['событие', 'число'],
#  'совершенно',
#  ['безраличный', 'асад'],
#  ['асад', 'оппозиция'],
#  'он',
#  ['легкий', 'мотоцикл'],
#  ['мотоцикл', 'год'],
#  ['дебил', 'мотик'],
#  ['становиться', 'мало'],
#  'мало',
#  ['здоровый', 'глаз'],
#  ['глаз', 'лоб'],
#  'наш',
#  ['система', 'защита'],
#  ['защита', 'информация'],
#  ['информация', 'государство'],
#  ['государство', 'подруга'],
#  'это',
#  ['расческа', 'барселона'],
#  'точно',
#  ['пригород', 'приз'],
#  ['приз', 'студия'],
#  'либо',
#  'либо',
#  ['хвойный', 'дерево'],
#  'явно',
#  ['юг', 'братислава'],
#  ['братислава', 'барселона'],
#  ['барселона', 'тиран'],
#  ['тиран', 'албания'],
#  'наш',
#  'это',
#  ['испания', 'кастилья'],
#  ['кастилья', 'италия'],
#  ['италия', 'париж'],
#  ['париж', 'прага'],
#  ['прага', 'душанбе'],
#  ['душанбе', 'лиссабон'],
#  ['лиссабон', 'наличие'],
#  ['наличие', 'серп'],
#  ['серп', 'молот'],
#  'однозначно',
#  'это',
#  ['город', 'италия'],
#  ['италия', 'португалия'],
#  ['португалия', 'греция'],
#  ['греция', 'испания'],
#  'мало',
#  ['романоязычный', 'страна'],
#  ['личный', 'состав'],
#  ['состав', 'часовой'],
#  ['часовой', 'пост'],
#  ['пост', 'город'],
#  ['город', 'весна'],
#  ['ворота', 'товарищ'],
#  ['товарищ', 'старшина'],
#  ['старшина', 'товарищ'],
#  ['товарищ', 'старшина'],
#  ['основной', 'рота'],
#  ['адекватный', 'сержант'],
#  ['старослужащий', 'старшина'],
#  'гораздо',
#  'легко',
#  'именно',
#  ['должный', 'образ'],
#  ['рядовой', 'боец'],
#  'всякий',
#  ['классический', 'вариант'],
#  'просто',
#  ['вопрос', 'офицер'],
#  ['докладывать', 'наверное'],
#  'наверное',
#  ['советский', 'устав'],
#  ['устав', 'караульная'],
#  ['гарнизонный', 'служба'],
#  ['служба', 'командир'],
#  ['командир', 'рота'],
#  ['рота', 'зам'],
#  ['зам', 'мочь'],
#  ['день', 'победа'],
#  ['победа', 'праздник'],
#  ['праздник', 'ураа'],
#  ['ураа', 'праздник'],
#  ['праздник', 'победа'],
#  ['победа', 'праздник'],
#  ['праздник', 'праздник'],
#  ['праздник', 'урррррааааа'],
#  ['день', 'победа'],
#  ['победа', 'действитель'],
#  'самый',
#  ['главный', 'праздник'],
#  ['звучать', 'гордо'],
#  'гордо',
#  ['день', 'победа'],
#  ['победа', 'день'],
#  ['день', 'победа'],
#  ['победа', 'праздник'],
#  ['праздник', 'праздник'],
#  ['праздник', 'день'],
#  ['день', 'победа'],
#  ['победа', 'праздник'],
#  ['праздник', 'победа'],
#  ['победа', 'й'],
#  ['й', 'годовщина'],
#  ['годовщина', 'победа'],
#  ['отечественный', 'война'],
#  ['война', 'праздник'],
#  ['праздник', 'день'],
#  ['день', 'победа'],
#  ['победа', 'день'],
#  ['великий', 'победа'],
#  ['победа', 'день'],
#  ['день', 'победа'],
#  ['победа', 'победа'],
#  ['победа', 'день'],
#  ['день', 'победа'],
#  ['победа', 'праздник'],
#  ['настоящий', 'праздник'],
#  'почему',
#  'каждый',
#  ['горький', 'горький'],
#  'мой',
#  'самый',
#  'некуда',
#  ['война', 'праздник'],
#  ['праздник', 'слеза'],
#  ['слеза', 'глаз'],
#  ['глаз', 'урааа'],
#  ['урааа', 'праздник'],
#  ['праздник', 'день'],
#  ['день', 'победа'],
#  ['праздник', 'день'],
#  ['день', 'победа'],
#  'ваш',
#  ['рейтинг', 'топ'],
#  ['судьба', 'запись'],
#  ['запись', 'мочь'],
#  ['мочь', 'ссылка'],
#  'гд',
#  'это',
#  ['точный', 'новость'],
#  'который',
#  'очень',
#  'весьма',
#  'весьма',
#  ['молодец', 'миронов'],
#  ['здравый', 'смысл'],
#  'вновь',
#  ['жизофренять', 'пора'],
#  'пора',
#  'какой',
#  ['политический', 'лагерь'],
#  ['интернет', 'герой'],
#  'два',
#  'такой',
#  'этот',
#  ['сборище', 'большинство'],
#  'свой',
#  ['хороший', 'человек'],
#  'который',
#  'идеалистически',
#  'который',
#  'реально',
#  ['душа', 'россия'],
#  ['россия', 'время'],
#  'такой',
#  ['народ', 'власть'],
#  ['тюрьма', 'исход'],
#  ['исход', 'жизнь'],
#  ['туповатый', 'согражданин'],
#  ['согражданин', 'большинство'],
#  'это',
#  ['личный', 'жизнь'],
#  'свой',
#  ['быдло', 'народ'],
#  ['народ', 'чернь'],
#  'се',
#  'это',
#  ['созыв', 'кс'],
#  'который',
#  'безусловно',
#  'особенно',
#  'определенно',
#  'пусть',
#  'сто',
#  'вполовину',
#  'мало',
#  'хотя',
#  'всякий',
#  ['лимоновый', 'илларионов'],
#  ['илларионов', 'пионтковский'],
#  ['реальный', 'уровень'],
#  ['уровень', 'поддержка'],
#  ['сильный', 'вождь'],
#  ['вождь', 'оппозиция'],
#  ['оппозиция', 'кс'],
#  'особенно',
#  'хотя',
#  'другой',
#  ['политический', 'сила'],
#  ['забывать', 'также'],
#  'также',
#  ['качество', 'площадка'],
#  ['площадка', 'случай'],
#  ['нужный', 'кс'],
#  ['кс', 'курия'],
#  ['курия', 'максимум'],
#  ['максимум', 'представитель'],
#  'бмд',
#  'бмп',
#  'бмп',
#  'бмп',
#  'полнуый',
#  'нпк',
#  ['план', 'м'],
#  ['следующий', 'год'],
#  ['большой', 'завод'],
#  'весь',
#  ['разница', 'рротиворечие'],
#  ['рротиворечие', 'пункт'],
#  'чучуть',
#  'мы',
#  ['нужный', 'гарантия'],
#  ['гарантия', 'оборудование'],
#  'наш',
#  'вообщемто',
#  ['приоритетный', 'доступ'],
#  'он',
#  'хотя',
#  'мы',
#  ['рыбка', 'т'],
#  ['т', 'д'],
#  'мы',
#  ['купить', 'полностью'],
#  'полностью',
#  'наш',
#  ['счет', 'станок'],
#  ['немой', 'изделие'],
#  ['изделие', 'интерес'],
#  ['побочный', 'использование'],
#  ['использование', 'оборудование'],
#  'пожалуйста',
#  'ты',
#  ['треть', 'стоимость'],
#  ['стоимость', 'оборудование'],
#  'весь',
#  'это',
#  ['частный', 'предприятие'],
#  'кстати',
#  'один',
#  'очень',
#  ['гибкий', 'штука'],
#  'никакой',
#  'полностью',
#  ['т', 'д'],
#  ['д', 'авто'],
#  'абсолютно',
#  'точно',
#  'также',
#  ['серобурмалиновый', 'цвет'],
#  'никакой',
#  ['аналог', 'мерс'],
#  ['мерс', 'бмв'],
#  ['бмв', 'волюнтаризм'],
#  ['волюнтаризм', 'покупатель'],
#  'ваш',
#  ['белый', 'цвет'],
#  ['цвет', 'аналог'],
#  ['аналог', 'заказаннойауди'],
#  ['заказаннойауди', 'сторона'],
#  'почемуто',
#  'обязательно',
#  ['заставлянт', 'покупатель'],
#  'либо',
#  ['итог', 'тендер'],
#  'ой',
#  ['оао', 'уралвагонзавод'],
#  ['уралвагонзавод', 'оао'],
#  ['сухой', 'оао'],
#  ['оао', 'туполев'],
#  ['туполев', 'оао'],
#  ['мотовилихинский', 'завод'],
#  ['завод', 'оао'],
#  ['конструкторский', 'бюро'],
#  ['бюро', 'машиностроение'],
#  ['прочий', 'тысяча'],
#  ['ясный', 'перец'],
#  ['перец', 'частник'],
#  'близко',
#  ['больший', 'часть'],
#  ['часть', 'оборонка'],
#  'этот',
#  ['оао', 'зао'],
#  'пусть',
#  ['акция', 'госсобственность'],
#  ['госсобственность', 'капо'],
#  'например',
#  'очень',
#  'именно',
#  'вообще',
#  'часто',
#  ['человеческий', 'мечта'],
#  ['любимый', 'книжка'],
#  ['книжка', 'пасьянс'],
#  'этот',
#  ['жестокий', 'реальность'],
#  'насчет',
#  ['вариант', 'пол'],
#  ['пол', 'удаленка'],
#  ['неделя', 'неделя'],
#  ['неделя', 'офис'],
#  ['офис', 'штат'],
#  'поэтому',
#  ['проект', 'менеджер'],
#  'заодно',
#  ['исполнитель', 'работа'],
#  ['работа', 'проект'],
#  ['проект', 'т'],
#  ['т', 'е'],
#  ['е', 'исполнитель'],
#  ['исполнитель', 'подчинение'],
#  'понятно',
#  'изначально',
#  ['построить', 'правильно'],
#  'правильно',
#  'именно',
#  'тот',
#  ['оперативный', 'работа'],
#  ['работа', 'дом'],
#  ['личный', 'производительность'],
#  ['производительность', 'план'],
#  ['план', 'выполнение'],
#  ['выполнение', 'оперативка'],
#  ['высокий', 'работа'],
#  ['работа', 'офис'],
#  'мало',
#  ['неизбежный', 'перерыв'],
#  ['перерыв', 'работа'],
#  ['домашний', 'дело'],
#  ['дело', 'план'],
#  ['план', 'контроль'],
#  ['контроль', 'работа'],
#  ['работа', 'исполнитель'],
#  'главное',
#  ['волна', 'неделя'],
#  ['рабочий', 'ритм'],
#  ['четкий', 'планирование'],
#  ['планирование', 'задача'],
#  ['задача', 'время'],
#  ['время', 'понимание'],
#  ['понимание', 'ответственность'],
#  ['ответственность', 'невыполнение'],
#  'это',
#  ['личный', 'опыт'],
#  'постоянно',
#  'хотя',
#  ['артем', 'горбунов'],
#  'тот',
#  'один',
#  'кстати',
#  ['описание', 'ресурс'],
#  ['ресурс', 'ссылка'],
#  'который',
#  ['привлечение', 'команда'],
#  ['правильный', 'человек'],
#  'это',
#  ['стартаповский', 'подход'],
#  ['подход', 'деньги'],
#  ['кончаться', 'рано'],
#  'рано',
#  'очевидно',
#  'хотя',
#  'тот',
#  ['пас', 'коровенка'],
#  ['коровенка', 'корова'],
#  ['корова', 'деревня'],
#  ['деревня', 'жизнь'],
#  ['жизнь', 'корова'],
#  'такой',
#  'такой',
#  ['страшный', 'рог'],
#  ['рог', 'ужас'],
#  'все',
#  'свой',
#  ['маленький', 'хозяйство'],
#  'оно',
#  ['корова', 'зорька'],
#  ['зорька', 'корова'],
#  ['страшный', 'зверь'],
#  ['опасаться', 'тож'],
#  'тож',
#  ['корова', 'молоко'],
#  ['детство', 'деревня'],
#  ['деревня', 'корова'],
#  'такой',
#  ['ответственный', 'дело'],
#  'ь',
#  'ь',
#  ['праздник', 'ч'],
#  ['ч', 'сан'],
#  ['сан', 'день'],
#  ['день', 'победа'],
#  'самый',
#  ['ьем', 'ус'],
#  ['ус', 'м'],
#  ['м', 'праздник'],
#  ['праздник', 'праздник'],
#  ['светлый', 'память'],
#  'все',
#  ['победа', 'праздник'],
#  ['праздник', 'праздник'],
#  ['праздник', 'день'],
#  ['день', 'победа'],
#  ['вечный', 'память'],
#  ['память', 'герой'],
#  ['герой', 'день'],
#  ['день', 'победа'],
#  ['великий', 'праздник'],
#  ['праздник', 'день'],
#  ['день', 'победа'],
#  ['победа', 'день'],
#  ['день', 'победа'],
#  ['победа', 'день'],
#  ['день', 'победа'],
#  ['победа', 'мир'],
#  ['мир', 'счастие'],
#  ['счастие', 'благополучие'],
#  'весь',
#  'мы',
#  'ура',
#  ['праздник', 'праздник'],
#  ['праздник', 'мир'],
#  ['мир', 'любовь'],
#  ['любовь', 'оксана'],
#  ['оксана', 'праздник'],
#  'ко',
#  ['френдмарафон', 'привет'],
#  ['привет', 'день'],
#  ['день', 'победа'],
#  ['победа', 'победа'],
#  ['победа', 'мочь'],
#  ['мочь', 'политика'],
#  ['политика', 'день'],
#  ['день', 'победа'],
#  ['победа', 'спасибо'],
#  ['спасибо', 'праздник'],
#  ['праздник', 'слава'],
#  ['бог', 'война'],
#  ['война', 'праздник'],
#  ['праздник', 'спасибо'],
#  ['спасибо', 'малик'],
#  ['великий', 'победа'],
#  'это',
#  ['политика', 'политика'],
#  ['политика', 'ссср'],
#  ['ссср', 'политика'],
#  ['честный', 'гражданин'],
#  ['гражданин', 'ссср'],
#  'весь',
#  'второй',
#  ['мировой', 'война'],
#  ['война', 'слово'],
#  ['слово', 'политика'],
#  ['грязный', 'слово'],
#  'оттого',
#  ['опошлять', 'нынче'],
#  'нынче',
#  'это',
#  ['политика', 'ссср'],
#  'второй',
#  ['мировой', 'война'],
#  'трудно',
#  ['смотреть', 'правда'],
#  'правда',
#  ['розовый', 'очки'],
#  ['фото', 'глаз'],
#  ['глаз', 'спасибо'],
#  'взаимно',
#  ['день', 'победа'],
#  'ничто',
#  'спасибочки',
#  'взаимно',
#  ['спасибо', 'праздник'],
#  ['вечный', 'память'],
#  'наверное',
#  ['праздник', 'праздник'],
#  'взаимно',
#  'взаимно',
#  'мой',
#  'свой',
#  ['спасибо', 'победа'],
#  ['вечный', 'память'],
#  ['память', 'герой'],
#  'взаимно',
#  ['праздник', 'праздник'],
#  ['праздник', 'праздник'],
#  ['праздник', 'победа'],
#  ['победа', 'дед'],
#  ['дед', 'отец'],
#  'сто',
#  ['грамм', 'победа'],
#  ['победа', 'спасибо'],
#  'взаимно',
#  ['спасибо', 'женечка'],
#  ['женечка', 'победа'],
#  ['победа', 'спасибо'],
#  'ервой',
#  'вай',
#  'столько',
#  'чу',
#  'чу',
#  'взаимно',
#  ['день', 'победа'],
#  'взаимно',
#  ['победа', 'праздник'],
#  ['праздник', 'победа'],
#  ['победа', 'спасибо'],
#  ['спасибо', 'праздник'],
#  ['праздник', 'победа'],
#  ['победа', 'победа'],
#  ['победа', 'праздник'],
#  ['праздник', 'победа'],
#  ['мариямполе', 'алитус'],
#  ['полсотни', 'пост'],
#  'это',
#  'отлично',
#  'сегодня',
#  ['скромный', 'калининград'],
#  ['калининград', 'фотосъемка'],
#  ['запрещать', 'вполне'],
#  'вполне',
#  'неплохо',
#  'ах',
#  ['паланга', 'студент'],
#  ['студент', 'калининград'],
#  'это',
#  'весьма',
#  ['романтичный', 'место'],
#  ['место', 'поездка'],
#  ['клевета', 'кениг'],
#  'давно',
#  ['й', 'форт'],
#  'благодаря',
#  'еще',
#  ['й', 'й'],
#  'второй',
#  'хотя',
#  ['е', 'год'],
#  ['год', 'паланга'],
#  'нлп',
#  ['господин', 'ашурков'],
#  ['полный', 'право'],
#  ['финансовый', 'отчет'],
#  ['денежный', 'средство'],
#  ['средство', 'средство'],
#  ['быть', 'далее'],
#  'далее',
#  ['решать', 'ответственно'],
#  'ответственно',
#  'свой',
#  ['избранный', 'член'],
#  ['член', 'кс'],
#  ['кс', 'ирония'],
#  ['ирония', 'большинство'],
#  ['большинство', 'член'],
#  ['член', 'ксо'],
#  ['ксо', 'агент'],
#  ['агент', 'встраивание'],
#  ['встраивание', 'оппозиция'],
#  ['системный', 'политика'],
#  'худо',
#  'бедно',
#  'свой',
#  ['определенный', 'количество'],
#  ['количество', 'гражданин'],
#  ['член', 'генсовет'],
#  ['единый', 'россия'],
#  ['россия', 'владимир'],
#  ['владимир', 'бурмат'],
#  'этот',
#  'вчера',
#  'свой',
#  ['представлять', 'скоро'],
#  'скоро',
#  ['немой', 'концепция'],
#  'это',
#  'просто',
#  'феноменально',
#  'четко',
#  ['офмцмальный', 'позиция'],
#  'относительно',
#  ['кс', 'кс'],
#  ['концепция', 'протопарламент'],
#  ['задача', 'создание'],
#  ['региональный', 'ксов'],
#  'весь',
#  ['территория', 'россия'],
#  ['потенциальный', 'источник'],
#  ['альтернативный', 'легитимность'],
#  'совершенно',
#  'недопустимо',
#  ['кс', 'проект'],
#  ['проект', 'организация'],
#  ['карманный', 'оппозиция'],
#  'благодаря',
#  ['республиканский', 'фракция'],
#  'все',
#  'понятно',
#  ['огромный', 'степень'],
#  'благодаря',
#  ['последовательный', 'деятельность'],
#  ['деятельность', 'направление'],
#  ['направление', 'хозяин'],
#  ['хозяин', 'блог'],
#  ['блог', 'кс'],
#  ['возможный', 'модель'],
#  ['модель', 'организация'],
#  ['протестный', 'движение'],
#  'весь',
#  'это',
#  'хотя',
#  'вполне',
#  'этот',
#  ['митинг', 'песня'],
#  ['молодой', 'человек'],
#  'это',
#  ['глубинный', 'результат'],
#  ['сказываться', 'возможно'],
#  'возможно',
#  'скоро',
#  ['потенциал', 'кс'],
#  'очень',
#  'быстро',
#  'лгбт',
#  'разумеется',
#  ['российский', 'обскурантизм'],
#  ['обскурантизм', 'дикость'],
#  ['православнутый', 'архаика'],
#  ['архаика', 'латиноамериканец'],
#  ['стоять', 'впереди'],
#  'впереди',
#  ['спорить', 'кажется'],
#  'кажется',
#  ['коммунизм', 'учение'],
#  ['учение', 'христос'],
#  'это',
#  ['конечный', 'счет'],
#  'один',
#  ['различный', 'слово'],
#  ['слово', 'коммунизм'],
#  'столько',
#  ['экономический', 'формация'],
#  'первый',
#  'духовно',
#  ['нравственный', 'состояние'],
#  ['состояние', 'общество'],
#  ['коммунистический', 'формация'],
#  ['коммунистический', 'способ'],
#  ['способ', 'производство'],
#  ['духовный', 'перестройка'],
#  ['перестройка', 'человечество'],
#  ['человечество', 'основа'],
#  'который',
#  'сначала',
#  'другой',
#  ['последний', 'очередь'],
#  ['очередь', 'забота'],
#  'это',
#  'столь',
#  ['настоящий', 'коммунар'],
#  ['коммунар', 'призыв'],
#  ['призыв', 'христос'],
#  ['христос', 'аскетизм'],
#  ['аскетизм', 'искоренение'],
#  ['искоренение', 'жажда'],
#  'благо',
#  ['признание', 'уважение'],
#  ['уважение', 'общество'],
#  ['общество', 'известность'],
#  ['известность', 'слава'],
#  ['слава', 'статус'],
#  ['статус', 'место'],
#  ['общественный', 'иерархия'],
#  ['иерархия', 'коммунизм'],
#  ['критерий', 'истина'],
#  'это',
#  ['практика', 'чавес'],
#  'публично',
#  ['серебряный', 'крестик'],
#  ['крестик', 'средневековье'],
#  ['российский', 'левак'],
#  ['православнутый', 'архаика'],
#  ['архаика', 'тысяча'],
#  ['магкоев', 'десяток'],
#  'нтр',
#  'эффективно',
#  ['земной', 'альянс'],
#  ['альянс', 'сообщество'],
#  ['сообщество', 'конгломерат'],
#  ['разный', 'страна'],
#  'внутри',
#  ['культурный', 'особенность'],
#  ['особенность', 'граница'],
#  ['граница', 'барьер'],
#  'мало',
#  'один',
#  'другой',
#  'просто',
#  ['автоматический', 'система'],
#  ['система', 'перевод'],
#  'близко',
#  ['друг', 'друг'],
#  'социально',
#  ['экономический', 'модель'],
#  ['модель', 'альянс'],
#  'естественно',
#  'причем',
#  ['красный', 'цвет'],
#  ['цвет', 'православие'],
#  ['православие', 'самодержавие'],
#  ['самодержавие', 'народностьперестройка'],
#  ['народностьперестройка', 'приватизация'],
#  ['хороший', 'император'],
#  ['император', 'позор'],
#  ['плохой', 'боярин'],
#  ['боярин', 'империя'],
#  'любой',
#  ['империя', 'протяжение'],
#  'весь',
#  ['история', 'человечество'],
#  'этот',
#  'один',
#  ['национальный', 'большинство'],
#  'менее',
#  'другой',
#  ['национальный', 'меньшинство'],
#  ['меньшинство', 'класс'],
#  ['ссср', 'империя'],
#  'серо',
#  'еще',
#  'какой',
#  'верно',
#  'поскольку',
#  'это',
#  ['социалистический', 'республика'],
#  ['социалистический', 'т'],
#  ['т', 'е'],
#  'такой',
#  ['законодательный', 'уровень'],
#  ['принцип', 'запрет'],
#  'любой',
#  ['форма', 'эксплуатация'],
#  ['эксплуатация', 'угнетение'],
#  ['угнетение', 'форма'],
#  ['форма', 'деятельность'],
#  ['деятельность', 'государство'],
#  ['развитие', 'социализация'],
#  ['социализация', 'личность'],
#  ['принудительный', 'порядок'],
#  ['привет', 'дебют'],
#  'давно',
#  'это',
#  'действительно',
#  'намного',
#  'дешево',
#  'раз',
#  'быстро',
#  'ежели',
#  ['пеший', 'поход'],
#  ['поход', 'время'],
#  'недавно',
#  ['купон', 'скидка'],
#  'очень',
#  'выгодно',
#  ['найсер', 'дайсер'],
#  ['дайсер', 'кухня'],
#  ['часовой', 'страдание'],
#  ['страдание', 'турция'],
#  ['пляжный', 'отдых'],
#  'давно',
#  'просто',
#  ['сарделька', 'море'],
#  'этот',
#  ['местный', 'менталитет'],
#  ['менталитет', 'хватание'],
#  ['хватание', 'рука'],
#  ['рука', 'т'],
#  ['т', 'п'],
#  'возможно',
#  ['год', 'жизнь'],
#  ['жизнь', 'кипр'],
#  'мой',
#  ['сознание', 'отпечаток'],
#  ['отпечаток', 'стамбул'],
#  'такой',
#  'довольно',
#  'свежо',
#  'особенно',
#  'оба',
#  ['лайнер', 'компания'],
#  'другой',
#  'дешево',
#  'такой',
#  ['саутгемптон', 'кобх'],
#  ['кобх', 'ирландия'],
#  ['ирландия', 'дублин'],
#  ['дублин', 'ливерпуль'],
#  ['ливерпуль', 'глазго'],
#  ['глазго', 'белфаст'],
#  ['белфаст', 'инвергордон'],
#  ['инвергордон', 'эдинбург'],
#  ['эдинбург', 'гавр'],
#  'почему',
#  ['руан', 'день'],
#  'боязно',
#  ['нестандартный', 'вид'],
#  ['вид', 'путешествие'],
#  ['путешествие', 'вероятность'],
#  ['вероятность', 'шторм'],
#  'очень',
#  'каждый',
#  'другой',
#  'туда',
#  ['теплый', 'время'],
#  ['время', 'год'],
#  'боязно',
#  ['билет', 'кораблик'],
#  'это',
#  ['полюбоваться', 'очень'],
#  'очень',
#  ['чехия', 'наметка'],
#  'давно',
#  ['прага', 'замок'],
#  'никак',
#  ['дело', 'вкус'],
#  ['вкус', 'статистика'],
#  'честно',
#  'оба',
#  ['круиз', 'длительность'],
#  ['длительность', 'неделя'],
#  'каждый',
#  'лишь',
#  ['неспокойный', 'море'],
#  ['море', 'британия'],
#  ['британия', 'лайнер'],
#  'слегка',
#  ['покачиваться', 'немного'],
#  'немного',
#  'мутно',
#  ['ходить', 'невозможно'],
#  'невозможно',
#  'такой',
#  'который',
#  ['настоящий', 'махина'],
#  ['махина', 'палуба'],
#  ['палуба', 'высота'],
#  ['большой', 'дом'],
#  ['дом', 'время'],
#  ['время', 'плавание'],
#  ['плавание', 'шторм'],
#  ['ощущаться', 'сухо'],
#  'самый',
#  ['декларация', 'образование'],
#  ['образование', 'ссср'],
#  ['причина', 'путь'],
#  ['путь', 'решение'],
#  ['решение', 'проблема'],
#  ['проблема', 'время'],
#  ['время', 'образование'],
#  ['советский', 'республика'],
#  ['республика', 'государство'],
#  ['государство', 'мир'],
#  ['лагерь', 'лагерь'],
#  ['лагерь', 'капитализм'],
#  ['капитализм', 'лагерь'],
#  ['лагерь', 'социализм'],
#  ['социализм', 'лагерь'],
#  ['лагерь', 'капитализм'],
#  ['национальный', 'вражда'],
#  ['вражда', 'неравенство'],
#  ['колониальный', 'рабство'],
#  ['рабство', 'шовинизм'],
#  ['национальный', 'угнетение'],
#  ['угнетение', 'погром'],
#  ['империалистический', 'зверство'],
#  ['зверство', 'война'],
#  ['война', 'лагерь'],
#  ['лагерь', 'социализм'],
#  ['взаимный', 'доверие'],
#  ['доверие', 'мир'],
#  ['национальный', 'свобода'],
#  ['свобода', 'равенство'],
#  ['мирный', 'сожительство'],
#  ['братский', 'сотрудничество'],
#  ['сотрудничество', 'народ'],
#  ['народ', 'попытка'],
#  ['капиталистический', 'мир'],
#  ['мир', 'протяжение'],
#  ['протяжение', 'десяток'],
#  ['десяток', 'год'],
#  ['вопрос', 'национальность'],
#  'путем',
#  ['свободный', 'развитие'],
#  ['развитие', 'народ'],
#  ['народ', 'система'],
#  ['система', 'эксплуатация'],
#  ['эксплуатация', 'человек'],
#  ['человек', 'человек'],
#  'наоборот',
#  ['национальный', 'противоречие'],
#  'самый',
#  ['существование', 'капитализм'],
#  ['капитализм', 'буржуазия'],
#  ['сотрудничество', 'народ'],
#  ['народ', 'лагерь'],
#  ['лагерь', 'совет'],
#  ['совет', 'условие'],
#  ['условие', 'диктатура'],
#  ['диктатура', 'пролетариат'],
#  'вокруг',
#  ['большинство', 'население'],
#  ['национальный', 'гнет'],
#  ['взаимный', 'доверие'],
#  ['братский', 'сотрудничество'],
#  ['сотрудничество', 'народ'],
#  'бмп',
#  'бмп',
#  ...]

# %%
first_five = extraPhrase[:10]
first_five
# Out:
# ['некоторые',
#  ['список', 'любовь'],
#  ['герой', 'р'],
#  ['растрелять', 'правда'],
#  'правда',
#  ['воевать', 'недавно'],
#  'недавно',
#  ['неплохой', 'репортаж'],
#  ['наградной', 'лист'],
#  ['лист', 'бой']]

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer() 
def sentimentWordsFunct(x):
    senti_list_temp = []    
    for i in x:
        if type(i) is list:
            y = ' '.join(i)
        else:
            y = ''.join(i) 

        vs = analyzer.polarity_scores(y)
        senti_list_temp.append((y, vs))
        senti_list_temp = [w for w in senti_list_temp if w]    
        sentiment_list  = []
    for j in senti_list_temp:
        first = j[0]
        second = j[1]
    
        for (k,v) in second.items():
            if k == 'compound':
                if v < 0.0:
                    sentiment_list.append((first, "Negative"))
                elif v == 0.0:
                    sentiment_list.append((first, "Neutral"))
                else:
                    sentiment_list.append((first, "Positive"))   
    
    return sentiment_list

# %%
sentimentWordsFunct(first_five)
# Out:
# [('некоторые', 'Neutral'),
#  ('список любовь', 'Neutral'),
#  ('герой р', 'Neutral'),
#  ('растрелять правда', 'Neutral'),
#  ('правда', 'Neutral'),
#  ('воевать недавно', 'Neutral'),
#  ('недавно', 'Neutral'),
#  ('неплохой репортаж', 'Neutral'),
#  ('наградной лист', 'Neutral'),
#  ('лист бой', 'Neutral')]
